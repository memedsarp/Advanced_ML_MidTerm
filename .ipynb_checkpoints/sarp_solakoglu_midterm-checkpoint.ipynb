# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
for col in ['Area', 'Perimeter']:
    df.loc[df.sample(frac=0.05, random_state=42).index, col] = np.nan

# %%
df.isnull().sum()
# Out:
# Area               681
# Perimeter          681
# MajorAxisLength      0
# MinorAxisLength      0
# AspectRation         0
# Eccentricity         0
# ConvexArea           0
# EquivDiameter        0
# Extent               0
# Solidity             0
# roundness            0
# Compactness          0
# ShapeFactor1         0
# ShapeFactor2         0
# ShapeFactor3         0
# ShapeFactor4         0
# Class                0
# dtype: int64

# %%
df.loc[df.sample(frac=0.35, random_state=1).index, 'Eccentricity'] = np.nan

# %%
df.isnull().sum()
# Out:
# Area                681
# Perimeter           681
# MajorAxisLength       0
# MinorAxisLength       0
# AspectRation          0
# Eccentricity       4764
# ConvexArea            0
# EquivDiameter         0
# Extent                0
# Solidity              0
# roundness             0
# Compactness           0
# ShapeFactor1          0
# ShapeFactor2          0
# ShapeFactor3          0
# ShapeFactor4          0
# Class                 0
# dtype: int64

# %%
df.describe().columns
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4'],
#       dtype='object')

# %% [markdown]
# # 2. Preprocessing

# %%
def z_score_noise(data, spread_val):
    min_max = []
    
    for col in data.columns:
        if data[col].dtype != "object":
            mean_val = data[col].mean()
            std_val = data[col].std()

            min_max.append([mean_val - spread_val*std_val, mean_val + spread_val*std_val])
    
    return min_max

# %%
ls = z_score_noise(df, 1.96) # z score for including the 95% of the data, cut out the 2.5% from each tail

# %%
# compare whether the 95% adjusted data points are below or above the actual min/max values in each column
# if so, adds the colname into the list
# this is the case if the data is not normally distributed. It may have a gamma distribution, poisson or any other
# In this case, we need to work for the data individually

col_list_z_adjusted = []

i=0
for col in df.describe().columns:
    #print("", df[col].min(), ls[i][0], "\n", df[col].max(), ls[i][1], "\n ----------\n")
    
    if df[col].min() > ls[i][0] or df[col].max() < ls[i][1]:
        col_list_z_adjusted.append(col)
    
    i+=1

# %%
col_list_z_adjusted
# Out:
# ['Area',
#  'Perimeter',
#  'MajorAxisLength',
#  'MinorAxisLength',
#  'Eccentricity',
#  'ConvexArea',
#  'EquivDiameter',
#  'Solidity',
#  'ShapeFactor2',
#  'ShapeFactor4']

# %%
i=0
for col in df.describe().columns:
    if col not in col_list_z_adjusted:
        df.loc[df[col]<ls[i][0],col] = ls[i][0]
        df.loc[df[col]>ls[i][1],col] = ls[i][1]
        
    i+=1

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   12930.000000  12930.000000     13611.000000     13611.000000
# mean    53020.594973    855.094134       320.141867       202.270714
# std     29283.485203    214.095166        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36321.250000    703.388500       253.303633       175.848170
# 50%     44645.000000    794.841500       296.883367       192.431733
# 75%     61342.750000    977.175250       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000   8847.000000   13611.000000   13611.000000  13611.000000
# mean       1.578522      0.751516   53768.200206     253.064220      0.751323
# std        0.235541      0.091268   29774.915817      59.177120      0.045007
# min        1.099752      0.218951   20684.000000     161.243764      0.653524
# 25%        1.432307      0.716318   36714.500000     215.068003      0.718634
# 50%        1.551124      0.764973   45178.000000     238.438026      0.759859
# 75%        1.707109      0.810466   62294.000000     279.446467      0.786851
# max        2.066732      0.911423  263261.000000     569.374358      0.845942
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987143      0.874346      0.799667      0.006595      0.001716
# std        0.004660      0.056657      0.060400      0.001032      0.000596
# min        0.919246      0.756623      0.678905      0.004353      0.000564
# 25%        0.985670      0.832096      0.762469      0.005900      0.001154
# 50%        0.988283      0.883157      0.801277      0.006645      0.001694
# 75%        0.990013      0.916869      0.834270      0.007271      0.002170
# max        0.994677      0.989941      0.920822      0.008774      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.642606      0.995063
# std        0.096350      0.004366
# min        0.449558      0.947687
# 25%        0.581359      0.993703
# 50%        0.642044      0.996386
# 75%        0.696006      0.997883
# max        0.837623      0.999733

# %% [markdown]
# ## 2.1. Individual Column Handling

# %% [markdown]
# ### 2.1.1. Area

# %%
plt.hist(df["Area"], bins=20)
plt.show()

# %%
# It seems to have two added distributions are in this col. An arbitrary value of 125000 is selected to divide them
dividing_line = 125000

plt.hist(df.loc[df["Area"]<dividing_line, "Area"], bins=20)

plt.show()

# %%
plt.hist(df.loc[df["Area"]>=dividing_line, "Area"], bins=20)
plt.show()

# %%
# we check if these different distributions are random or depend on the type of bean

# %%
df.loc[df["Area"]>=dividing_line, "Class"].value_counts()
# Out:
# Class
# BOMBAY    491
# Name: count, dtype: int64

# %%
df.loc[df["Area"]<dividing_line, "Class"].value_counts()
# Out:
# Class
# DERMASON    3381
# SIRA        2497
# SEKER       1926
# HOROZ       1821
# CALI        1548
# BARBUNYA    1264
# BOMBAY         2
# Name: count, dtype: int64

# %%
# We have a perfect separation. We will use this property to determine the min and max values for each distribution
# we will also update the dividing line which was arbitrary. We will include these two bombay beans as well.


df.loc[(df["Area"]<dividing_line) & (df["Class"] == "BOMBAY"), "Area"].min()
# Out:
# np.float64(114004.0)

# %%
# the value below is the min value for bombay.
# We now need to check if there are any different sort between this min value and our arbitrary dividing line

df.loc[(df["Area"]>=114004) & (df["Area"]<dividing_line), ["Area", "Class"]]
# Out:
#           Area     Class
# 3348  115967.0  BARBUNYA
# 3349  114004.0    BOMBAY
# 3350  117034.0    BOMBAY
# 5498  114858.0      CALI
# 5499  115608.0      CALI
# 5500  116272.0      CALI

# %%
# Since there are overlaps, we will continue with each sort of bean individually.
# We'll check whether they have different distributions for the feature area

for bean in df["Class"].unique():
    plt.hist(df.loc[df["Class"]==bean, "Area"], alpha=.35, label=bean)
    
plt.legend()    
plt.show()

# %% [markdown]
# # Starting over Again

# %% [markdown]
# # 1. Preprocessing

# %%
# We'll adjust our approach and apply noise correction in each feature depending on the type of bean
# This means we'll undone the previous actions

df = pd.read_excel("Dry_Bean_Dataset.xlsx")

for col in ['Area', 'Perimeter']:
    df.loc[df.sample(frac=0.05, random_state=42).index, col] = np.nan

df.loc[df.sample(frac=0.35, random_state=1).index, 'Eccentricity'] = np.nan

# %%
df.isnull().sum()
# Out:
# Area                681
# Perimeter           681
# MajorAxisLength       0
# MinorAxisLength       0
# AspectRation          0
# Eccentricity       4764
# ConvexArea            0
# EquivDiameter         0
# Extent                0
# Solidity              0
# roundness             0
# Compactness           0
# ShapeFactor1          0
# ShapeFactor2          0
# ShapeFactor3          0
# ShapeFactor4          0
# Class                 0
# dtype: int64

# %%
df.head()
# Out:
#       Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395.0    610.291       208.178117       173.888747      1.197191
# 1  28734.0    638.018       200.524796       182.734419      1.097356
# 2  29380.0    624.110       212.826130       175.931143      1.209713
# 3  30008.0    645.884       210.557999       182.516516      1.153638
# 4  30140.0    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4           NaN       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   12930.000000  12930.000000     13611.000000     13611.000000
# mean    53020.594973    855.094134       320.141867       202.270714
# std     29283.485203    214.095166        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36321.250000    703.388500       253.303633       175.848170
# 50%     44645.000000    794.841500       296.883367       192.431733
# 75%     61342.750000    977.175250       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000   8847.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.751516   53768.200206     253.064220      0.749733
# std        0.246678      0.091268   29774.915817      59.177120      0.049086
# min        1.024868      0.218951   20684.000000     161.243764      0.555315
# 25%        1.432307      0.716318   36714.500000     215.068003      0.718634
# 50%        1.551124      0.764973   45178.000000     238.438026      0.759859
# 75%        1.707109      0.810466   62294.000000     279.446467      0.786851
# max        2.430306      0.911423  263261.000000     569.374358      0.866195
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987143      0.873282      0.799864      0.006564      0.001716
# std        0.004660      0.059520      0.061713      0.001128      0.000596
# min        0.919246      0.489618      0.640577      0.002778      0.000564
# 25%        0.985670      0.832096      0.762469      0.005900      0.001154
# 50%        0.988283      0.883157      0.801277      0.006645      0.001694
# 75%        0.990013      0.916869      0.834270      0.007271      0.002170
# max        0.994677      0.990685      0.987303      0.010451      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.643590      0.995063
# std        0.098996      0.004366
# min        0.410339      0.947687
# 25%        0.581359      0.993703
# 50%        0.642044      0.996386
# 75%        0.696006      0.997883
# max        0.974767      0.999733

# %% [markdown]
# ## 1.1. Missing Values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
# in order to calculate the missing values in area and perimeter,
# I'll build two models with features that have no nan values
# In order to do so, we need to check for best correlated features with each

df_corr = df.loc[:,df.columns[:-2]]
df_corr.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966646         0.931882         0.951565
# Perimeter        0.966646   1.000000         0.977268         0.913233
# MajorAxisLength  0.931882   0.977268         1.000000         0.826052
# MinorAxisLength  0.951565   0.913233         0.826052         1.000000
# AspectRation     0.241807   0.384963         0.550335        -0.009161
# Eccentricity     0.266009   0.388511         0.539361         0.017730
# ConvexArea       0.999939   0.967630         0.932607         0.951339
# EquivDiameter    0.984947   0.991345         0.961733         0.948539
# Extent           0.054698  -0.021414        -0.078062         0.145957
# Solidity        -0.194838  -0.302946        -0.284302        -0.155831
# roundness       -0.357505  -0.547755        -0.596358        -0.210344
# Compactness     -0.268059  -0.406486        -0.568377        -0.015066
# ShapeFactor1    -0.847874  -0.864692        -0.773609        -0.947204
# ShapeFactor2    -0.639333  -0.767389        -0.859238        -0.471347
# ShapeFactor3    -0.272105  -0.408042        -0.568185        -0.019326
#
#                  AspectRation  Eccentricity  ConvexArea  EquivDiameter  \
# Area                 0.241807      0.266009    0.999939       0.984947
# Perimeter            0.384963      0.388511    0.967630       0.991345
# MajorAxisLength      0.550335      0.539361    0.932607       0.961733
# MinorAxisLength     -0.009161      0.017730    0.951339       0.948539
# AspectRation         1.000000      0.925316    0.243301       0.303647
# Eccentricity         0.925316      1.000000    0.267002       0.315700
# ConvexArea           0.243301      0.267002    1.000000       0.985226
# EquivDiameter        0.303647      0.315700    0.985226       1.000000
# Extent              -0.370184     -0.317989    0.052564       0.028383
# Solidity            -0.267754     -0.294679   -0.206191      -0.231648
# roundness           -0.766979     -0.720952   -0.362083      -0.435945
# Compactness         -0.987687     -0.970845   -0.269922      -0.327650
# ShapeFactor1         0.024593      0.021434   -0.847950      -0.892741
# ShapeFactor2        -0.837841     -0.857941   -0.640862      -0.713069
# ShapeFactor3        -0.978592     -0.981454   -0.274024      -0.330389
#
#                    Extent  Solidity  roundness  Compactness  ShapeFactor1  \
# Area             0.054698 -0.194838  -0.357505    -0.268059     -0.847874
# Perimeter       -0.021414 -0.302946  -0.547755    -0.406486     -0.864692
# MajorAxisLength -0.078062 -0.284302  -0.596358    -0.568377     -0.773609
# MinorAxisLength  0.145957 -0.155831  -0.210344    -0.015066     -0.947204
# AspectRation    -0.370184 -0.267754  -0.766979    -0.987687      0.024593
# Eccentricity    -0.317989 -0.294679  -0.720952    -0.970845      0.021434
# ConvexArea       0.052564 -0.206191  -0.362083    -0.269922     -0.847950
# EquivDiameter    0.028383 -0.231648  -0.435945    -0.327650     -0.892741
# Extent           1.000000  0.191389   0.344411     0.354212     -0.141616
# Solidity         0.191389  1.000000   0.607150     0.303766      0.153388
# roundness        0.344411  0.607150   1.000000     0.768086      0.230273
# Compactness      0.354212  0.303766   0.768086     1.000000     -0.009394
# ShapeFactor1    -0.141616  0.153388   0.230273    -0.009394      1.000000
# ShapeFactor2     0.237956  0.343559   0.782824     0.868939      0.469197
# ShapeFactor3     0.347624  0.307662   0.763126     0.998686     -0.008320
#
#                  ShapeFactor2  ShapeFactor3
# Area                -0.639333     -0.272105
# Perimeter           -0.767389     -0.408042
# MajorAxisLength     -0.859238     -0.568185
# MinorAxisLength     -0.471347     -0.019326
# AspectRation        -0.837841     -0.978592
# Eccentricity        -0.857941     -0.981454
# ConvexArea          -0.640862     -0.274024
# EquivDiameter       -0.713069     -0.330389
# Extent               0.237956      0.347624
# Solidity             0.343559      0.307662
# roundness            0.782824      0.763126
# Compactness          0.868939      0.998686
# ShapeFactor1         0.469197     -0.008320
# ShapeFactor2         1.000000      0.872971
# ShapeFactor3         0.872971      1.000000

# %% [markdown]
# ### 1.1.1. Missing Values

# %%
# column Area seems perfectly correlating with column ConvexArea
# whereas column Perimeter is perfectly correlating with EquivDiameter
# What we need is to find the y=ax+b function so that we can calculate the missing values for each features

# for eccentricity, on the other hand,
# I'll apply a multilinear regression since there is no perfect correlation with any of the single features.

df.loc[:,["Area", "ConvexArea"]]
# Out:
#           Area  ConvexArea
# 0      28395.0       28715
# 1      28734.0       29172
# 2      29380.0       29690
# 3      30008.0       30724
# 4      30140.0       30417
# ...        ...         ...
# 13606  42097.0       42508
# 13607  42101.0       42494
# 13608  42139.0       42569
# 13609  42147.0       42667
# 13610  42159.0       42600
#
# [13611 rows x 2 columns]

# %%
# The code below is written by me for another project.
# Thus, this is not a copy paste class and it is appropriate to use it here

import random

class ML:
    import numpy as np
    import random
    
    # init function
    
    def __init__(self, data, target, simple_model=True):
        self.data = data
        self.target = target
        self.simple_model = simple_model
        self.weights = None
        self.learning_rate = 0.02
        
    # parameter changing
    
    def set_learning_rate(self, lr):
        self.learning_rate = lr
    
    def LinearRegression(self, stochastic=False):
        if self.simple_model:
            a = ((self.data - self.data.mean()) * (self.target - self.target.mean())).sum() / ((self.data - self.data.mean()) ** 2).sum()
            b = self.target.mean() - (a * self.data.mean())
            
            return (a, b)
        else:
            
            self.initiate_weights()
        
            epoch = 10000
            for i in range(epoch):
                error = self.calculate_error()
                self.gradient_descent(error)
            
            return self.weights
    
    ## helper methods
    # Linear Regression
    
    def initiate_weights(self):
        num_features = self.data.shape[1]
        self.weights = np.array([random.random() for x in range(num_features)])
    
    def forward_pass(self):
        return (self.data@self.weights)
    
    def calculate_error(self):
        return self.forward_pass() - self.target
    
    def gradient_descent(self, error):
        self.weights = self.weights - self.learning_rate * (2 * (error.mean() * self.weights))

# %%
# a and b values are below. Whenever we need to calculate a nan value,
# we simply need to apply f(x)=ax + b

ml = ML(df["Area"], df["ConvexArea"])
a, b = ml.LinearRegression()
print(a, b)
# Out:
# 1.01528226796459 -62.66970723353734

# %%
df.loc[df["Area"].isnull(), "Area"]  = np.array(df.loc[df["Area"].isnull(), ["ConvexArea"]] * a + b)

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  12930.000000     13611.000000     13611.000000
# mean    53122.466222    855.094134       320.141867       202.270714
# std     29376.457222    214.095166        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36371.000000    703.388500       253.303633       175.848170
# 50%     44710.000000    794.841500       296.883367       192.431733
# 75%     61459.500000    977.175250       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000   8847.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.751516   53768.200206     253.064220      0.749733
# std        0.246678      0.091268   29774.915817      59.177120      0.049086
# min        1.024868      0.218951   20684.000000     161.243764      0.555315
# 25%        1.432307      0.716318   36714.500000     215.068003      0.718634
# 50%        1.551124      0.764973   45178.000000     238.438026      0.759859
# 75%        1.707109      0.810466   62294.000000     279.446467      0.786851
# max        2.430306      0.911423  263261.000000     569.374358      0.866195
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987143      0.873282      0.799864      0.006564      0.001716
# std        0.004660      0.059520      0.061713      0.001128      0.000596
# min        0.919246      0.489618      0.640577      0.002778      0.000564
# 25%        0.985670      0.832096      0.762469      0.005900      0.001154
# 50%        0.988283      0.883157      0.801277      0.006645      0.001694
# 75%        0.990013      0.916869      0.834270      0.007271      0.002170
# max        0.994677      0.990685      0.987303      0.010451      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.643590      0.995063
# std        0.098996      0.004366
# min        0.410339      0.947687
# 25%        0.581359      0.993703
# 50%        0.642044      0.996386
# 75%        0.696006      0.997883
# max        0.974767      0.999733

# %% [markdown]
# ### 1.1.2. Perimeter

# %%
df.loc[:,["Perimeter", "EquivDiameter"]]
# Out:
#        Perimeter  EquivDiameter
# 0        610.291     190.141097
# 1        638.018     191.272750
# 2        624.110     193.410904
# 3        645.884     195.467062
# 4        620.134     195.896503
# ...          ...            ...
# 13606    759.696     231.515799
# 13607    757.499     231.526798
# 13608    759.321     231.631261
# 13609    763.779     231.653248
# 13610    772.237     231.686223
#
# [13611 rows x 2 columns]

# %%
ml = ML(df["Perimeter"], df["EquivDiameter"])
a, b = ml.LinearRegression()
print(a, b)
# Out:
# 0.27373600806670595 18.994165112110977

# %%
df.loc[df["Perimeter"].isnull(), "Perimeter"] = np.array(df.loc[df["Perimeter"].isnull(), ["EquivDiameter"]] * a + b)

# %%
df.isnull().sum()
# Out:
# Area                  0
# Perimeter             0
# MajorAxisLength       0
# MinorAxisLength       0
# AspectRation          0
# Eccentricity       4764
# ConvexArea            0
# EquivDiameter         0
# Extent                0
# Solidity              0
# roundness             0
# Compactness           0
# ShapeFactor1          0
# ShapeFactor2          0
# ShapeFactor3          0
# ShapeFactor4          0
# Class                 0
# dtype: int64

# %% [markdown]
# ### 1.1.3. Eccentricity

# %%
# We select the four highest correlated features
# ShapeFactor3, Compactness, AspectRation, and ShapeFactor2

df_corr.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966646         0.931882         0.951565
# Perimeter        0.966646   1.000000         0.977268         0.913233
# MajorAxisLength  0.931882   0.977268         1.000000         0.826052
# MinorAxisLength  0.951565   0.913233         0.826052         1.000000
# AspectRation     0.241807   0.384963         0.550335        -0.009161
# Eccentricity     0.266009   0.388511         0.539361         0.017730
# ConvexArea       0.999939   0.967630         0.932607         0.951339
# EquivDiameter    0.984947   0.991345         0.961733         0.948539
# Extent           0.054698  -0.021414        -0.078062         0.145957
# Solidity        -0.194838  -0.302946        -0.284302        -0.155831
# roundness       -0.357505  -0.547755        -0.596358        -0.210344
# Compactness     -0.268059  -0.406486        -0.568377        -0.015066
# ShapeFactor1    -0.847874  -0.864692        -0.773609        -0.947204
# ShapeFactor2    -0.639333  -0.767389        -0.859238        -0.471347
# ShapeFactor3    -0.272105  -0.408042        -0.568185        -0.019326
#
#                  AspectRation  Eccentricity  ConvexArea  EquivDiameter  \
# Area                 0.241807      0.266009    0.999939       0.984947
# Perimeter            0.384963      0.388511    0.967630       0.991345
# MajorAxisLength      0.550335      0.539361    0.932607       0.961733
# MinorAxisLength     -0.009161      0.017730    0.951339       0.948539
# AspectRation         1.000000      0.925316    0.243301       0.303647
# Eccentricity         0.925316      1.000000    0.267002       0.315700
# ConvexArea           0.243301      0.267002    1.000000       0.985226
# EquivDiameter        0.303647      0.315700    0.985226       1.000000
# Extent              -0.370184     -0.317989    0.052564       0.028383
# Solidity            -0.267754     -0.294679   -0.206191      -0.231648
# roundness           -0.766979     -0.720952   -0.362083      -0.435945
# Compactness         -0.987687     -0.970845   -0.269922      -0.327650
# ShapeFactor1         0.024593      0.021434   -0.847950      -0.892741
# ShapeFactor2        -0.837841     -0.857941   -0.640862      -0.713069
# ShapeFactor3        -0.978592     -0.981454   -0.274024      -0.330389
#
#                    Extent  Solidity  roundness  Compactness  ShapeFactor1  \
# Area             0.054698 -0.194838  -0.357505    -0.268059     -0.847874
# Perimeter       -0.021414 -0.302946  -0.547755    -0.406486     -0.864692
# MajorAxisLength -0.078062 -0.284302  -0.596358    -0.568377     -0.773609
# MinorAxisLength  0.145957 -0.155831  -0.210344    -0.015066     -0.947204
# AspectRation    -0.370184 -0.267754  -0.766979    -0.987687      0.024593
# Eccentricity    -0.317989 -0.294679  -0.720952    -0.970845      0.021434
# ConvexArea       0.052564 -0.206191  -0.362083    -0.269922     -0.847950
# EquivDiameter    0.028383 -0.231648  -0.435945    -0.327650     -0.892741
# Extent           1.000000  0.191389   0.344411     0.354212     -0.141616
# Solidity         0.191389  1.000000   0.607150     0.303766      0.153388
# roundness        0.344411  0.607150   1.000000     0.768086      0.230273
# Compactness      0.354212  0.303766   0.768086     1.000000     -0.009394
# ShapeFactor1    -0.141616  0.153388   0.230273    -0.009394      1.000000
# ShapeFactor2     0.237956  0.343559   0.782824     0.868939      0.469197
# ShapeFactor3     0.347624  0.307662   0.763126     0.998686     -0.008320
#
#                  ShapeFactor2  ShapeFactor3
# Area                -0.639333     -0.272105
# Perimeter           -0.767389     -0.408042
# MajorAxisLength     -0.859238     -0.568185
# MinorAxisLength     -0.471347     -0.019326
# AspectRation        -0.837841     -0.978592
# Eccentricity        -0.857941     -0.981454
# ConvexArea          -0.640862     -0.274024
# EquivDiameter       -0.713069     -0.330389
# Extent               0.237956      0.347624
# Solidity             0.343559      0.307662
# roundness            0.782824      0.763126
# Compactness          0.868939      0.998686
# ShapeFactor1         0.469197     -0.008320
# ShapeFactor2         1.000000      0.872971
# ShapeFactor3         0.872971      1.000000

# %%
data = df.loc[~df["Eccentricity"].isnull(), ["ShapeFactor2", "ShapeFactor3", "AspectRation", "Compactness"]]
target = df.loc[~df["Eccentricity"].isnull(), "Eccentricity"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(data, target)
# Out:
# LinearRegression()

# %%
model.score(data, target)
# Out:
# 0.9985923641404488

# %%
(model.coef_, model.intercept_)
# Out:
# (array([ 0.3643494 , -7.55600922,  0.44880671, 12.42836078]),
#  np.float64(-5.038314069424181))

# %%
data.iloc[0]
# Out:
# ShapeFactor2    0.003147
# ShapeFactor3    0.834222
# AspectRation    1.197191
# Compactness     0.913358
# Name: 0, dtype: float64

# %%
df.loc[df["Eccentricity"].isnull()].shape[0]
# Out:
# 4764

# %%
missing_data = df.loc[df["Eccentricity"].isnull(), ["ShapeFactor2", "ShapeFactor3", "AspectRation", "Compactness"]]

result = []

for i in range(df.loc[df["Eccentricity"].isnull()].shape[0]):
    result.append(missing_data.iloc[i] @ model.coef_ + model.intercept_)
result
# Out:
# [np.float64(0.384023626502521),
#  np.float64(0.4951568553263588),
#  np.float64(0.5163383547778784),
#  np.float64(0.7480319846992014),
#  np.float64(0.7913134098109174),
#  np.float64(0.7438306734752977),
#  np.float64(0.7329049381794333),
#  np.float64(0.7428606212860425),
#  np.float64(0.779389878555989),
#  np.float64(0.6611744611542356),
#  np.float64(0.7122116714347753),
#  np.float64(0.8129808065505006),
#  np.float64(0.8193148724951529),
#  ...]

# %%
df.loc[df["Eccentricity"].isnull(), "Eccentricity"] = result

# %%
df_corr = df.loc[:,df.columns[:-2]]
df_corr.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.726750         0.931800         0.951467
# Perimeter        0.726750   1.000000         0.741731         0.696037
# MajorAxisLength  0.931800   0.741731         1.000000         0.826052
# MinorAxisLength  0.951467   0.696037         0.826052         1.000000
# AspectRation     0.241855   0.288195         0.550335        -0.009161
# Eccentricity     0.267773   0.294404         0.542298         0.019573
# ConvexArea       0.999857   0.735627         0.932607         0.951339
# EquivDiameter    0.984880   0.753919         0.961733         0.948539
# Extent           0.054484  -0.030010        -0.078062         0.145957
# Solidity        -0.196879  -0.240215        -0.284302        -0.155831
# roundness       -0.357654  -0.418012        -0.596358        -0.210344
# Compactness     -0.268186  -0.305386        -0.568377        -0.015066
# ShapeFactor1    -0.847820  -0.659779        -0.773609        -0.947204
# ShapeFactor2    -0.639313  -0.582016        -0.859238        -0.471347
# ShapeFactor3    -0.272261  -0.306821        -0.568185        -0.019326
#
#                  AspectRation  Eccentricity  ConvexArea  EquivDiameter  \
# Area                 0.241855      0.267773    0.999857       0.984880
# Perimeter            0.288195      0.294404    0.735627       0.753919
# MajorAxisLength      0.550335      0.542298    0.932607       0.961733
# MinorAxisLength     -0.009161      0.019573    0.951339       0.948539
# AspectRation         1.000000      0.924939    0.243301       0.303647
# Eccentricity         0.924939      1.000000    0.269413       0.318900
# ConvexArea           0.243301      0.269413    1.000000       0.985226
# EquivDiameter        0.303647      0.318900    0.985226       1.000000
# Extent              -0.370184     -0.319370    0.052564       0.028383
# Solidity            -0.267754     -0.294790   -0.206191      -0.231648
# roundness           -0.766979     -0.722981   -0.362083      -0.435945
# Compactness         -0.987687     -0.970834   -0.269922      -0.327650
# ShapeFactor1         0.024593      0.019912   -0.847950      -0.892741
# ShapeFactor2        -0.837841     -0.860557   -0.640862      -0.713069
# ShapeFactor3        -0.978592     -0.981536   -0.274024      -0.330389
#
#                    Extent  Solidity  roundness  Compactness  ShapeFactor1  \
# Area             0.054484 -0.196879  -0.357654    -0.268186     -0.847820
# Perimeter       -0.030010 -0.240215  -0.418012    -0.305386     -0.659779
# MajorAxisLength -0.078062 -0.284302  -0.596358    -0.568377     -0.773609
# MinorAxisLength  0.145957 -0.155831  -0.210344    -0.015066     -0.947204
# AspectRation    -0.370184 -0.267754  -0.766979    -0.987687      0.024593
# Eccentricity    -0.319370 -0.294790  -0.722981    -0.970834      0.019912
# ConvexArea       0.052564 -0.206191  -0.362083    -0.269922     -0.847950
# EquivDiameter    0.028383 -0.231648  -0.435945    -0.327650     -0.892741
# Extent           1.000000  0.191389   0.344411     0.354212     -0.141616
# Solidity         0.191389  1.000000   0.607150     0.303766      0.153388
# roundness        0.344411  0.607150   1.000000     0.768086      0.230273
# Compactness      0.354212  0.303766   0.768086     1.000000     -0.009394
# ShapeFactor1    -0.141616  0.153388   0.230273    -0.009394      1.000000
# ShapeFactor2     0.237956  0.343559   0.782824     0.868939      0.469197
# ShapeFactor3     0.347624  0.307662   0.763126     0.998686     -0.008320
#
#                  ShapeFactor2  ShapeFactor3
# Area                -0.639313     -0.272261
# Perimeter           -0.582016     -0.306821
# MajorAxisLength     -0.859238     -0.568185
# MinorAxisLength     -0.471347     -0.019326
# AspectRation        -0.837841     -0.978592
# Eccentricity        -0.860557     -0.981536
# ConvexArea          -0.640862     -0.274024
# EquivDiameter       -0.713069     -0.330389
# Extent               0.237956      0.347624
# Solidity             0.343559      0.307662
# roundness            0.782824      0.763126
# Compactness          0.868939      0.998686
# ShapeFactor1         0.469197     -0.008320
# ShapeFactor2         1.000000      0.872971
# ShapeFactor3         0.872971      1.000000

# %% [markdown]
# ## 1.2. Outlier Detection

# %%
# we will update the z score noise function as well. This will now include the sort of bean as well
# For easier use, data type will be changed from array to dictionary
    
def z_score_noise(data, beans, spread_val):
    
    dict_min_max = {} 
    
    for bean in beans:
        dict_min_max[bean] = {}
    
    for col in data.columns:
        if data[col].dtype != "object":
            for bean in beans:
                mean_val = data.loc[df["Class"]==bean, col].mean()
                std_val = data.loc[df["Class"]==bean, col].std()

                dict_min_max[bean][col] = [mean_val - spread_val*std_val, mean_val + spread_val*std_val]

    return dict_min_max

# %%
dict_min_max = z_score_noise(df, df["Class"].unique(), 1.96)

# %%
# by calculating z score with the help of classes, we can now assume our distributions are normal

col_list_z_adjusted = []

for bean in dict_min_max.keys():
    for feature in dict_min_max[bean].keys():
        if dict_min_max[bean][feature][0] < df.loc[(df["Class"]==bean), feature].min() or dict_min_max[bean][feature][0] > df.loc[(df["Class"]==bean), feature].max():
                col_list_z_adjusted.append(bean + "-" + feature)
                
col_list_z_adjusted
# Out:
# []

# %%
for bean in df["Class"].unique():
    for col in df.columns:
        if df[col].dtype != "object":
            df.loc[(df["Class"]==bean) & (df[col]<dict_min_max[bean][col][0]), col] = dict_min_max[bean][col][0]
            df.loc[(df["Class"]==bean) & (df[col]>dict_min_max[bean][col][1]), col] = dict_min_max[bean][col][1]
# Out:
# /tmp/ipykernel_72915/2093400900.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30814.788762880038' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[(df["Class"]==bean) & (df[col]<dict_min_max[bean][col][0]), col] = dict_min_max[bean][col][0]

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53061.773773    835.825044       320.099219       202.188557
# std     29194.642993    226.150833        85.342852        44.687208
# min     22980.886247    375.262918       206.055384       141.059284
# 25%     36442.500000    691.121000       253.482906       175.872143
# 50%     44716.000000    784.541000       296.738268       192.332584
# 75%     61454.000000    966.244500       376.480180       216.685916
# max    219629.863408   1985.370000       697.417598       420.019199
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.582699      0.751730   53706.980869     253.047321      0.749981
# std        0.245208      0.090390   29592.152350      58.913543      0.048687
# min        1.084024      0.448942   23265.358076     172.710659      0.558841
# 25%        1.428997      0.715491   36777.500000     215.285460      0.718874
# 50%        1.552359      0.765326   45214.000000     238.472733      0.759859
# 75%        1.704569      0.811562   62282.500000     279.441910      0.786851
# max        2.291424      0.908679  222506.686558     530.419898      0.853945
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987345      0.874380      0.799758      0.006560      0.001712
# std        0.003932      0.057380      0.061309      0.001119      0.000591
# min        0.973576      0.705116      0.654586      0.003033      0.000580
# 25%        0.985670      0.835673      0.762943      0.005904      0.001153
# 50%        0.988283      0.883091      0.800981      0.006644      0.001694
# 75%        0.990013      0.916743      0.834971      0.007271      0.002165
# max        0.994677      0.990685      0.953146      0.008926      0.003179
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.643280      0.995224
# std        0.098260      0.003785
# min        0.425915      0.979351
# 25%        0.582082      0.993718
# 50%        0.641571      0.996386
# 75%        0.697176      0.997883
# max        0.905354      0.999733

# %%
# Since there are overlaps, we will continue with each sort of bean individually.
# We'll check whether they have different distributions for the feature area

for bean in df["Class"].unique():
    plt.hist(df.loc[df["Class"]==bean, "Perimeter"], alpha=.35, label=bean)
    
plt.legend()    
plt.show()

# %% [markdown]
# ## 1.3. Feature Scaling (StandardScaler)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data = df.iloc[:,:-2]

# %%
X_raw = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %%
X_raw.describe()
# Out:
#                Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count  1.361100e+04  1.361100e+04     1.361100e+04     1.361100e+04
# mean   3.341028e-17  3.341028e-16     5.345645e-16     1.336411e-16
# std    1.000037e+00  1.000037e+00     1.000037e+00     1.000037e+00
# min   -1.030394e+00 -2.036601e+00    -1.336351e+00    -1.367987e+00
# 25%   -5.692786e-01 -6.398798e-01    -7.806015e-01    -5.889243e-01
# 50%   -2.858771e-01 -2.267775e-01    -2.737407e-01    -2.205628e-01
# 75%    2.874683e-01  5.767135e-01     6.606650e-01     3.244305e-01
# max    5.705643e+00  5.083276e+00     4.421369e+00     4.874743e+00
#
#        AspectRation  Eccentricity    ConvexArea  EquivDiameter        Extent  \
# count  1.361100e+04  1.361100e+04  1.361100e+04   1.361100e+04  1.361100e+04
# mean   6.347954e-16  1.085834e-16  1.002308e-16  -3.675131e-16  2.192550e-16
# std    1.000037e+00  1.000037e+00  1.000037e+00   1.000037e+00  1.000037e+00
# min   -2.033751e+00 -3.349919e+00 -1.028744e+00  -1.363687e+00 -3.926016e+00
# 25%   -6.268470e-01 -4.009343e-01 -5.721146e-01  -6.409944e-01 -6.389297e-01
# 50%   -1.237359e-01  1.504218e-01 -2.870117e-01  -2.473985e-01  2.028999e-01
# 75%    4.970222e-01  6.619502e-01  2.898010e-01   4.480389e-01  7.573271e-01
# max    2.890401e+00  1.736412e+00  5.704415e+00   4.708302e+00  2.135421e+00
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  1.361100e+04  1.361100e+04  1.361100e+04  1.361100e+04  1.361100e+04
# mean   2.245171e-14  3.341028e-16 -8.352571e-16  5.345645e-16 -3.341028e-17
# std    1.000037e+00  1.000037e+00  1.000037e+00  1.000037e+00  1.000037e+00
# min   -3.502102e+00 -2.949974e+00 -2.367945e+00 -3.152838e+00 -1.915665e+00
# 25%   -4.258436e-01 -6.745859e-01 -6.005021e-01 -5.858304e-01 -9.460813e-01
# 50%    2.387003e-01  1.518164e-01  1.995241e-02  7.567298e-02 -3.122357e-02
# 75%    6.787734e-01  7.383190e-01  5.743635e-01  6.359268e-01  7.653439e-01
# max    1.865213e+00  2.027003e+00  2.501966e+00  2.115591e+00  2.482288e+00
#
#        ShapeFactor3
# count  1.361100e+04
# mean  -4.009234e-16
# std    1.000037e+00
# min   -2.212234e+00
# 25%   -6.228421e-01
# 50%   -1.739275e-02
# 75%    5.485267e-01
# max    2.667259e+00

# %% [markdown]
# ## 1.3. Categorical Encoding

# %%
# Since there is only one categorical class in the dataset, we will convert only that
# This is the class feature
# We just need to apply the index number in df["Class"].unique() so that we kan keep track of the outputs

df["Class"]

y = df["Class"].apply(lambda x: np.where(df["Class"].unique() == x)[0][0])
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 13606    6
# 13607    6
# 13608    6
# 13609    6
# 13610    6
# Name: Class, Length: 13611, dtype: int64

# %% [markdown]
# # 2. Feature Selection and Dimensionality Reduction

# %% [markdown]
# ## 2.1. PCA

# %%
from sklearn.decomposition import PCA

# %%
df_scaled = X_raw

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 13606    6
# 13607    6
# 13608    6
# 13609    6
# 13610    6
# Name: Class, Length: 13611, dtype: int64

# %%
pca = PCA(n_components=3)

# %%
pca.fit(X_raw)
# Out:
# PCA(n_components=3)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.56874993, 0.27814303, 0.06505773])

# %%
# because the third variable explains merely 6% as opposed to the 27% of the second, we can omit that as well
# we'll proceed with 2 components only
# These 2 components amount to more than 80% of the variance in the dataset

# %%
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.56874993, 0.27814303])

# %%
pd.DataFrame(df_pca)
# Out:
#               0         1
# 0     -4.713208  2.121325
# 1     -4.927738  2.856518
# 2     -4.551325  2.035783
# 3     -4.586222  2.364609
# 4     -5.523279  3.470759
# ...         ...       ...
# 13606 -1.012914 -0.502954
# 13607 -1.511534  0.465493
# 13608 -1.386338  0.126671
# 13609 -1.127756 -0.199632
# 13610 -0.668412 -0.722805
#
# [13611 rows x 2 columns]

# %%
plt.scatter(df_pca[:,0], df_pca[:,1])
plt.show()

# %%
pd.DataFrame(df_pca).iloc[50:75]
# Out:
#            0         1
# 50 -4.474793  2.388505
# 51 -4.404676  2.228779
# 52 -4.881463  2.912025
# 53 -4.989538  3.038126
# 54 -4.494178  2.414976
# 55 -4.426340  2.390354
# 56 -4.030161  2.005723
# 57 -4.995792  2.929672
# 58 -4.643139  2.609698
# 59 -4.214925  1.958242
# 60 -4.629247  2.587646
# 61 -4.617335  2.488203
# 62 -4.615139  2.651907
# 63 -4.247779  1.631680
# 64 -4.040442  1.832394
# 65 -4.436539  2.235459
# 66 -4.711263  3.015850
# 67 -3.431122  1.089239
# 68 -4.329474  2.149056
# 69 -4.402314  2.321362
# 70 -5.427116  3.271074
# 71 -5.135908  3.446902
# 72 -4.408883  2.463227
# 73 -4.877440  2.907967
# 74 -4.393794  2.258414

# %% [markdown]
# ## 2.2. LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis(n_components=3)

# %%
df_lda = lda.fit_transform(df_scaled, y)

# %%
prediction_val = []

for i in range(df_scaled.shape[0]):
    prediction_val.append(lda.predict([df_scaled.loc[i]])[0])
# Out:
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# /home/sarp-solakoglu/sklearn-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   warnings.warn(
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
(prediction_val == y).sum() / len(y)
# Out:
# np.float64(0.9088972154874734)

# %%
lda.coef_, lda.intercept_
# Out:
# (array([[-1.00875061e+01,  6.85491108e-02, -1.03814262e+01,
#          -3.47766987e+01, -4.49958231e+01,  2.51755732e+01,
#           5.09753659e+01, -2.88241161e+01, -2.20770234e-01,
#           1.05352272e+00,  1.61088029e+00, -3.63058453e+02,
#          -1.86326514e+01, -1.68221197e+01,  3.62838902e+02],
#         [-5.71445932e+01, -1.70600218e+00,  6.21682328e+00,
#           1.85598922e+01,  6.05872383e+01, -2.33215083e+01,
#           4.57504278e+00,  5.83293617e+01,  5.72199417e-01,
#           1.25195750e-01, -1.05602870e+01,  4.17632356e+02,
#           1.43074159e+01,  1.04681353e+01, -3.76830824e+02],
#         [ 1.34544674e+02,  2.81192121e+00, -1.62232085e+01,
#           1.22652973e+02,  6.98433620e+01, -2.89131384e+01,
#          -9.84539930e+01,  1.10228740e+01,  3.07983984e-01,
#          -1.30802531e+00,  3.70664910e+00,  4.07473674e+02,
#           7.62207675e+01,  1.64698292e+01, -3.86230245e+02],
#         [ 1.55118566e+01,  1.92614582e-01,  3.25429727e+01,
#           3.26896493e+01, -7.59622175e+00, -1.99555622e+01,
#          -9.90681407e+01,  6.52805181e+01,  5.29592667e-01,
#          -1.64526243e+00,  1.96698832e+00,  1.08475446e+02,
#           2.02796938e+01,  2.52498053e+01, -1.49082271e+02],
#         [ 1.52727119e+01,  1.52077912e-01, -3.96972481e+00,
#           7.49456204e+00, -7.40336329e+01,  4.96130070e+01,
#          -2.82650940e+01,  2.38220054e+00, -1.31240812e-01,
#           5.12230550e-02, -1.17827315e+00, -6.30896761e+02,
#           2.19069089e-01, -6.04369401e+00,  5.96046044e+02],
#         [ 8.00319189e+00,  2.50192782e-01, -8.14888700e+00,
#          -1.68720874e+01,  2.01607734e+01, -2.06158531e+01,
#           1.64713756e+01, -2.59557545e+01, -8.95029332e-02,
#           1.10959589e-01,  6.61782696e-01,  1.76373644e+02,
#          -1.55720453e+01, -8.46884783e+00, -1.75224928e+02],
#         [-1.41190979e+01, -1.74312800e-01, -7.38275426e-01,
#          -1.16546763e+01,  2.16093786e+01, -3.91712274e+00,
#           3.23111494e+01, -1.89000652e+01, -2.38011290e-01,
#           1.89599583e-01,  1.71506901e+00,  1.53903358e+02,
#          -3.76864490e+00,  1.26374878e+00, -1.35355804e+02]]),
#  array([ -14.42244515,  -15.85113908, -195.24288127,  -13.65906211,
#          -17.60731776,   -4.11915516,   -8.29504988]))

# %%
pd.DataFrame(df_lda).head()
# Out:
#           0         1         2
# 0 -3.121696 -3.137526  0.077640
# 1 -3.482486 -3.476298  2.248794
# 2 -3.263420 -3.144493 -0.027810
# 3 -2.856547 -2.741770  1.707010
# 4 -3.845918 -3.933071 -0.628765

# %% [markdown]
# ## 2.3. Data We Have (raw, pca, lda)

# %%
X_raw.head()
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0 -0.771293  -0.997309        -1.264915        -0.486215     -1.572221
# 1 -0.771293  -0.874701        -1.264915        -0.435356     -1.979379
# 2 -0.771293  -0.936202        -1.257012        -0.486215     -1.521155
# 3 -0.771293  -0.839917        -1.264915        -0.440233     -1.749845
# 4 -0.771293  -0.953784        -1.264915        -0.266513     -2.033751
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0     -2.233934   -0.773618      -0.919269  0.286366  0.384449   1.457826
# 1     -3.349919   -0.773618      -0.919269  0.698103 -0.600029   0.220533
# 2     -2.091046   -0.773618      -0.919269  0.577843  0.563208   1.280447
# 3     -2.800347   -0.773618      -0.919269  0.671671 -0.727673   0.515118
# 4     -3.349919   -0.773618      -0.919269  0.474831  0.902647   1.925774
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3
# 0     1.852962      0.385001      2.427992      1.943318
# 1     2.501966      0.374679      2.482288      2.667259
# 2     1.778198      0.385001      2.259538      1.858318
# 3     2.097160      0.385001      2.482288      2.223933
# 4     2.501966      0.122891      2.482288      2.667259

# %%
pd.DataFrame(df_pca)
# Out:
#               0         1
# 0     -4.713208  2.121325
# 1     -4.927738  2.856518
# 2     -4.551325  2.035783
# 3     -4.586222  2.364609
# 4     -5.523279  3.470759
# ...         ...       ...
# 13606 -1.012914 -0.502954
# 13607 -1.511534  0.465493
# 13608 -1.386338  0.126671
# 13609 -1.127756 -0.199632
# 13610 -0.668412 -0.722805
#
# [13611 rows x 2 columns]

# %%
pd.DataFrame(df_lda)
# Out:
#               0         1         2
# 0     -3.121696 -3.137526  0.077640
# 1     -3.482486 -3.476298  2.248794
# 2     -3.263420 -3.144493 -0.027810
# 3     -2.856547 -2.741770  1.707010
# 4     -3.845918 -3.933071 -0.628765
# ...         ...       ...       ...
# 13606 -1.936655 -0.924427 -0.112114
# 13607 -2.002280 -1.288073  0.556196
# 13608 -2.081308 -1.280964  0.472057
# 13609 -1.838196 -0.954395  0.488894
# 13610 -1.794539 -0.307630 -0.193227
#
# [13611 rows x 3 columns]

# %% [markdown]
# # 3. Modeling and Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def train_test_split_func(X_raw, y, test_size, random_state):
    X_train, X_test, y_train, y_test = train_test_split(X_raw, y, test_size=0.33, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
models = [LogisticRegression, GaussianNB, DecisionTreeClassifier,
          RandomForestClassifier, GradientBoostingClassifier]

# data_on_hand = [data_1, data_2, data_3]

accuracy_dict = {}
precision_score_dict = {}
recall_score_dict = {}
f1_score_dict = {}


i=0
for single_model in models:
    accuracy_dict[i] = []
    precision_score_dict[i] = []
    recall_score_dict[i] = []
    f1_score_dict[i] = []
    
    dfs = [train_test_split_func(X_raw, y, .33, i),
          train_test_split_func(df_pca, y, .33, i),
          train_test_split_func(df_lda, y, .33, i),]
    j=0
    for processed_data in dfs:
        model = single_model()
        model.fit(processed_data[0], processed_data[2])
        
        accuracy_dict[i].append(accuracy_score(processed_data[3], model.predict(processed_data[1])))
        precision_score_dict[i].append(precision_score(processed_data[3], model.predict(processed_data[1]), average=None))
        recall_score_dict[i].append(recall_score(processed_data[3], model.predict(processed_data[1]), average=None))
        f1_score_dict[i].append(f1_score(processed_data[3], model.predict(processed_data[1]), average=None))
        
        j+=1
    i+=1

# %%
accuracy_dict
# Out:
# {0: [0.9294300979519146, 0.8593054318788959, 0.890026714158504],
#  1: [0.8853517364203027, 0.8486197684772929, 0.8840160284951024],
#  2: [0.9592609082813891, 0.8296972395369546, 0.8898040961709706],
#  3: [0.9695013357079252, 0.844612644701692, 0.916073018699911],
#  4: [0.97506678539626, 0.8515138023152271, 0.917853962600178]}

# %%
precision_score_dict
# Out:
# {0: [array([0.97090352, 0.96478873, 1.        , 0.90070922, 0.975     ,
#          0.85394456, 0.93333333]),
#   array([0.95807453, 0.68965517, 1.        , 0.69618056, 0.96656051,
#          0.83765502, 0.87687188]),
#   array([0.81068702, 0.93607306, 1.        , 0.91917293, 0.9734375 ,
#          0.87486157, 0.85253054])],
#  1: [array([0.95129376, 0.80128205, 1.        , 0.85657371, 0.95962733,
#          0.82896237, 0.87821612]),
#   array([0.9591195 , 0.69255663, 1.        , 0.67475728, 0.94907407,
#          0.82071269, 0.86390041]),
#   array([0.80267062, 0.9138322 , 1.        , 0.89279113, 0.97464342,
#          0.83586957, 0.8870822 ])],
#  2: [array([0.9850075 , 0.91163793, 1.        , 0.94817658, 0.99843505,
#          0.94348328, 0.95242215]),
#   array([0.94470046, 0.56818182, 1.        , 0.62872154, 0.94851794,
#          0.82669789, 0.86261449]),
#   array([0.87755102, 0.91196388, 1.        , 0.89259259, 0.97464342,
#          0.84736251, 0.85665529])],
#  3: [array([0.98789713, 0.98368298, 1.        , 0.95063985, 0.99687011,
#          0.95124717, 0.9567474 ]),
#   array([0.95377504, 0.62603878, 1.        , 0.65494137, 0.95461659,
#          0.83920188, 0.86759868]),
#   array([0.86562942, 0.92710706, 1.        , 0.92120075, 0.97356143,
#          0.90150637, 0.9061116 ])],
#  4: [array([1.        , 0.98387097, 1.        , 0.9559633 , 1.        ,
#          0.95578231, 0.96373057]),
#   array([0.95503876, 0.66850829, 1.        , 0.67567568, 0.953125  ,
#          0.84551887, 0.86552567]),
#   array([0.86666667, 0.925     , 1.        , 0.91992551, 0.975039  ,
#          0.90034762, 0.91400709])]}

# %%
precision_score_dict
# Out:
# {0: [array([0.97090352, 0.96478873, 1.        , 0.90070922, 0.975     ,
#          0.85394456, 0.93333333]),
#   array([0.95807453, 0.68965517, 1.        , 0.69618056, 0.96656051,
#          0.83765502, 0.87687188]),
#   array([0.81068702, 0.93607306, 1.        , 0.91917293, 0.9734375 ,
#          0.87486157, 0.85253054])],
#  1: [array([0.95129376, 0.80128205, 1.        , 0.85657371, 0.95962733,
#          0.82896237, 0.87821612]),
#   array([0.9591195 , 0.69255663, 1.        , 0.67475728, 0.94907407,
#          0.82071269, 0.86390041]),
#   array([0.80267062, 0.9138322 , 1.        , 0.89279113, 0.97464342,
#          0.83586957, 0.8870822 ])],
#  2: [array([0.9850075 , 0.91163793, 1.        , 0.94817658, 0.99843505,
#          0.94348328, 0.95242215]),
#   array([0.94470046, 0.56818182, 1.        , 0.62872154, 0.94851794,
#          0.82669789, 0.86261449]),
#   array([0.87755102, 0.91196388, 1.        , 0.89259259, 0.97464342,
#          0.84736251, 0.85665529])],
#  3: [array([0.98789713, 0.98368298, 1.        , 0.95063985, 0.99687011,
#          0.95124717, 0.9567474 ]),
#   array([0.95377504, 0.62603878, 1.        , 0.65494137, 0.95461659,
#          0.83920188, 0.86759868]),
#   array([0.86562942, 0.92710706, 1.        , 0.92120075, 0.97356143,
#          0.90150637, 0.9061116 ])],
#  4: [array([1.        , 0.98387097, 1.        , 0.9559633 , 1.        ,
#          0.95578231, 0.96373057]),
#   array([0.95503876, 0.66850829, 1.        , 0.67567568, 0.953125  ,
#          0.84551887, 0.86552567]),
#   array([0.86666667, 0.925     , 1.        , 0.91992551, 0.975039  ,
#          0.90034762, 0.91400709])]}

# %%
recall_score_dict
# Out:
# {0: [array([0.95481928, 0.91333333, 0.90449438, 0.96212121, 0.97805643,
#          0.9112628 , 0.8969697 ]),
#   array([0.92921687, 0.57777778, 1.        , 0.7594697 , 0.95141066,
#          0.84527873, 0.91255411]),
#   array([0.7996988 , 0.91111111, 1.        , 0.92613636, 0.97648903,
#          0.89874858, 0.84588745])],
#  1: [array([0.94126506, 0.83333333, 1.        , 0.81439394, 0.96865204,
#          0.82707622, 0.88658009]),
#   array([0.9186747 , 0.47555556, 1.        , 0.78977273, 0.96394984,
#          0.83845279, 0.9012987 ]),
#   array([0.81475904, 0.89555556, 1.        , 0.91477273, 0.96394984,
#          0.87485779, 0.85021645])],
#  2: [array([0.98945783, 0.94      , 1.        , 0.93560606, 1.        ,
#          0.93060296, 0.95324675]),
#   array([0.92620482, 0.5       , 1.        , 0.67992424, 0.95297806,
#          0.80318544, 0.8969697 ]),
#   array([0.84186747, 0.89777778, 1.        , 0.91287879, 0.96394984,
#          0.8589306 , 0.86926407])],
#  3: [array([0.98343373, 0.93777778, 1.        , 0.98484848, 0.9984326 ,
#          0.95449374, 0.95757576]),
#   array([0.93222892, 0.50222222, 1.        , 0.7405303 , 0.95611285,
#          0.81342435, 0.91341991]),
#   array([0.92168675, 0.90444444, 1.        , 0.92992424, 0.98119122,
#          0.8850967 , 0.88571429])],
#  4: [array([0.99096386, 0.94888889, 1.        , 0.98674242, 0.9984326 ,
#          0.95904437, 0.96623377]),
#   array([0.92771084, 0.53777778, 1.        , 0.75757576, 0.95611285,
#          0.81569966, 0.91948052]),
#   array([0.92018072, 0.90444444, 1.        , 0.93560606, 0.97962382,
#          0.88395904, 0.89264069])]}

# %%
f1_score_dict
# Out:
# {0: [array([0.96279423, 0.93835616, 0.94985251, 0.93040293, 0.97652582,
#          0.88167309, 0.91479029]),
#   array([0.94342508, 0.62877872, 1.        , 0.72644928, 0.95892575,
#          0.8414496 , 0.89435723]),
#   array([0.80515542, 0.92342342, 1.        , 0.92264151, 0.97496088,
#          0.88664422, 0.849196  ])],
#  1: [array([0.94625284, 0.81699346, 1.        , 0.83495146, 0.96411856,
#          0.82801822, 0.88237829]),
#   array([0.93846154, 0.56389987, 1.        , 0.72774869, 0.95645412,
#          0.8294879 , 0.88220339]),
#   array([0.80866966, 0.90460157, 1.        , 0.90364827, 0.96926714,
#          0.8549194 , 0.86825818])],
#  2: [array([0.98722765, 0.92560175, 1.        , 0.94184938, 0.99921691,
#          0.93699885, 0.95283427]),
#   array([0.93536122, 0.53191489, 1.        , 0.6533212 , 0.95074277,
#          0.81477207, 0.87945671]),
#   array([0.85933897, 0.90481523, 1.        , 0.90262172, 0.96926714,
#          0.85310734, 0.86291362])],
#  3: [array([0.98566038, 0.96018203, 1.        , 0.96744186, 0.99765074,
#          0.95286769, 0.9571614 ]),
#   array([0.9428789 , 0.55733662, 1.        , 0.69511111, 0.95536413,
#          0.82611207, 0.88991987]),
#   array([0.89277899, 0.91563555, 1.        , 0.92554194, 0.97736144,
#          0.89322618, 0.89579685])],
#  4: [array([0.99546142, 0.96606335, 1.        , 0.97110904, 0.99921569,
#          0.95741056, 0.96498054]),
#   array([0.94117647, 0.59605911, 1.        , 0.71428571, 0.95461659,
#          0.83034163, 0.89168766]),
#   array([0.89262235, 0.91460674, 1.        , 0.92769953, 0.97732604,
#          0.89207807, 0.90319755])]}

# %%
# GradientBoostingClassifier for the raw data is the best model with better results for each metric.
# Therefore I'll plot its ROC-AUC curve using one-vs-all method, meaning, there will be 7 plots for each class
# Below are the mean and standard deviations for each dataset (raw, pca, lda)

# %% [markdown]
# # 3.1. Performance Metrics

# %% [markdown]
# ## 3.1.1. Accuracy, Precision, Recall, and F1 Score

# %%
ls = []

print("The Accuracy Score:\n")
for i in range(3):
    for key in accuracy_dict.keys():
        ls.append(accuracy_dict[key][i])
    print(f"The mean for the model {i+1} is: {np.array(ls).mean()}, the std for the model {i+1} is: {np.array(ls).std()}")
# Out:
# The Accuracy Score:
#
# The mean for the model 1 is: 0.9437221727515583, the std for the model 1 is: 0.0331658665679735
# The mean for the model 2 is: 0.8952359750667853, the std for the model 2 is: 0.054303020936636796
# The mean for the model 3 is: 0.8966755713861679, the std for the model 3 is: 0.045155567335642896

# %%
ls = []

print("The Precision Score:\n")
for i in range(3):
    for key in precision_score_dict.keys():
        ls.append(precision_score_dict[key][i].mean())
    print(f"The mean for the model {i+1} is: {np.array(ls).mean()}, the std for the model {i+1} is: {np.array(ls).std()}")
# Out:
# The Precision Score:
#
# The mean for the model 1 is: 0.9514351141117766, the std for the model 1 is: 0.03031627665468106
# The mean for the model 2 is: 0.8989192286732944, the std for the model 2 is: 0.05734394896990399
# The mean for the model 3 is: 0.9043320860681447, the std for the model 3 is: 0.047876299890303835

# %%
ls = []

print("The recall Score:\n")
for i in range(3):
    for key in recall_score_dict.keys():
        ls.append(recall_score_dict[key][i].mean())
    print(f"The mean for the model {i+1} is: {np.array(ls).mean()}, the std for the model {i+1} is: {np.array(ls).std()}")
# Out:
# The recall Score:
#
# The mean for the model 1 is: 0.9488039832838355, the std for the model 1 is: 0.03112438950795746
# The mean for the model 2 is: 0.8943301397542264, the std for the model 2 is: 0.05919223466046837
# The mean for the model 3 is: 0.9013759380334189, the std for the model 3 is: 0.049855452861587574

# %%
ls = []

print("The F1 Score:\n")
for i in range(3):
    for key in f1_score_dict.keys():
        ls.append(f1_score_dict[key][i].mean())
    print(f"The mean for the model {i+1} is: {np.array(ls).mean()}, the std for the model {i+1} is: {np.array(ls).std()}")
# Out:
# The F1 Score:
#
# The mean for the model 1 is: 0.9498868965879383, the std for the model 1 is: 0.03071998764287889
# The mean for the model 2 is: 0.8956877327404584, the std for the model 2 is: 0.05888154053978317
# The mean for the model 3 is: 0.9021853543542899, the std for the model 3 is: 0.049408742867263516

# %% [markdown]
# ## 3.1.2 ROC-AUC Curve (One-vs-All)

# %%
from sklearn.metrics import roc_curve, auc

# %%
X_train, X_test, y_train, y_test = train_test_split(X_raw, y, test_size=0.33, random_state=42)

# %%
n_classes = len(y.unique())

# %%
model = GradientBoostingClassifier()

model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_hat = model.predict(X_test)
y_score = model.predict_proba(X_test)

# %%
class_order = df["Class"].unique()
class_order
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

# %%
# From then on, ready-codes from the scikit-learn documentation page are used for ROC-AUC display

class_of_interest = 0
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)

# %%
class_of_interest = 1
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)

# %%
class_of_interest = 2
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)

# %%
class_of_interest = 3
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)

# %%
class_of_interest = 4
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)

# %%
class_of_interest = 5
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)

# %%
class_of_interest = 6
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id

import matplotlib.pyplot as plt

from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test[:, class_id],
    y_score[:, class_id],
    name=f"{class_of_interest} vs the rest",
    color="darkorange",
    plot_chance_level=True,
    despine=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"One-vs-Rest ROC curves:\nClass={class_order[class_of_interest]} vs (All)",
)
